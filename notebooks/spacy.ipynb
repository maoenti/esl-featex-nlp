# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("All digital computers use binary, or two-valued, digits instead than decimal, or ten-valued, digits to represent and store data.")
# doc = nlp("He refused answering the question.")

counter = 0
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.is_alpha, token.is_stop)
    if len(list(token.ancestors)) == 0:
        print(f'"{token.text}" is a main verb')
        for child in token.children:
            if child.pos_ == 'VERB':
                print(child.text)
    
    # print(counter, token.text, token.tag_)
    # counter += 1
displacy.render(doc, style="dep")
# Out:
# All all DET DT det True True
# digital digital ADJ JJ amod True False
# computers computer NOUN NNS nsubj True False
# use use VERB VBP ROOT True False
# "use" is a main verb
# binary binary ADJ JJ amod True False
# , , PUNCT , punct False False
# or or CCONJ CC cc True True
# two two NUM CD advmod True True
# - - PUNCT HYPH punct False False
# valued value VERB VBN conj True False
# , , PUNCT , punct False False
# digits digit NOUN NNS dobj True False
# instead instead ADV RB advmod True False
# than than ADP IN cc True True
# decimal decimal ADJ JJ conj True False
# , , PUNCT , punct False False
# or or CCONJ CC cc True True
# ten ten NUM CD advmod True True
# - - PUNCT HYPH punct False False
# valued value VERB VBN conj True False
# , , PUNCT , punct False False
# digits digit NOUN NNS conj True False
# to to PART TO aux True True
# represent represent VERB VB relcl True False
# and and CCONJ CC cc True True
# store store NOUN NN compound True False
# ...

# %%
from pathlib import Path
doc = nlp("They played soccer yesterday.")
svg = displacy.render(doc, style="dep", jupyter=False)
displacy.render(doc, style="dep")
output_path = Path("./brown-fox.svg")
output_path.open("w", encoding="utf-8").write(svg)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1c4d6f3f11b24f7fa45f1f181f625ebb-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">played</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
for token in doc:
    print(token, token.tag_)
# Out:
# They PRP
# played VBD
# soccer NN
# yesterday NN
# . .
